# %%
import xarray as xr
import numpy as np
#import h5netcdf
import netCDF4
from matplotlib import pyplot as plt

# %%
icesm_data_d18O_850 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.085001-089912.nc')
icesm_data_d18O_850_surf = icesm_data_d18O_850.isel(z_t=0);
icesm_data_d18O_850_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 600, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
#     TLONG                 (nlat, nlon) float64 320.6 321.7 322.8 ... 319.4 319.8
# ...

# %%
icesm_data_d18O_900 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.090001-099912.nc')
icesm_data_d18O_900_surf = icesm_data_d18O_900.isel(z_t=0);
icesm_data_d18O_900_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1000 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.100001-109912.nc')
icesm_data_d18O_1000_surf = icesm_data_d18O_1000.isel(z_t=0);
icesm_data_d18O_1000_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1100 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.110001-119912.nc')
icesm_data_d18O_1100_surf = icesm_data_d18O_1100.isel(z_t=0);
icesm_data_d18O_1100_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1200 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.120001-129912.nc')
icesm_data_d18O_1200_surf = icesm_data_d18O_1200.isel(z_t=0);
icesm_data_d18O_1200_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1300 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.130001-139912.nc')
icesm_data_d18O_1300_surf = icesm_data_d18O_1300.isel(z_t=0);
icesm_data_d18O_1300_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1400 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.140001-149912.nc')
icesm_data_d18O_1400_surf = icesm_data_d18O_1400.isel(z_t=0);
icesm_data_d18O_1400_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1500 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.150001-159912.nc')
icesm_data_d18O_1500_surf = icesm_data_d18O_1500.isel(z_t=0);
icesm_data_d18O_1500_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1600 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.160001-169912.nc')
icesm_data_d18O_1600_surf = icesm_data_d18O_1600.isel(z_t=0);
icesm_data_d18O_1600_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1700 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.170001-179912.nc')
icesm_data_d18O_1700_surf = icesm_data_d18O_1700.isel(z_t=0);
icesm_data_d18O_1700_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_d18O_1800 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.180001-184912.nc')
icesm_data_d18O_1800_surf = icesm_data_d18O_1800.isel(z_t=0);
icesm_data_d18O_1800_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 600, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
#     TLONG                 (nlat, nlon) float64 320.6 321.7 322.8 ... 319.4 319.8
# ...

# %%
icesm_data_d18O_1850 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.R18O.185001-200512.nc')
icesm_data_d18O_1850_surf = icesm_data_d18O_1850.isel(z_t=0);
icesm_data_d18O_1850_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1872, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_850 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.085001-089912.nc')
icesm_data_salt_850_surf = icesm_data_salt_850.isel(z_t=0);
icesm_data_salt_850_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 600, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
#     TLONG                 (nlat, nlon) float64 320.6 321.7 322.8 ... 319.4 319.8
# ...

# %%
icesm_data_salt_900 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.090001-099912.nc')
icesm_data_salt_900_surf = icesm_data_salt_900.isel(z_t=0);
icesm_data_salt_900_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1000 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.100001-109912.nc')
icesm_data_salt_1000_surf = icesm_data_salt_1000.isel(z_t=0);
icesm_data_salt_1000_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1100 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.110001-119912.nc')
icesm_data_salt_1100_surf = icesm_data_salt_1100.isel(z_t=0);
icesm_data_salt_1100_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1200 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.120001-129912.nc')
icesm_data_salt_1200_surf = icesm_data_salt_1200.isel(z_t=0);
icesm_data_salt_1200_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1300 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.130001-139912.nc')
icesm_data_salt_1300_surf = icesm_data_salt_1300.isel(z_t=0);
icesm_data_salt_1300_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1400 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.140001-149912.nc')
icesm_data_salt_1400_surf = icesm_data_salt_1400.isel(z_t=0);
icesm_data_salt_1400_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1500 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.150001-159912.nc')
icesm_data_salt_1500_surf = icesm_data_salt_1500.isel(z_t=0);
icesm_data_salt_1500_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1600 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.160001-169912.nc')
icesm_data_salt_1600_surf = icesm_data_salt_1600.isel(z_t=0);
icesm_data_salt_1600_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1700 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.170001-179912.nc')
icesm_data_salt_1700_surf = icesm_data_salt_1700.isel(z_t=0);
icesm_data_salt_1700_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1200, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
icesm_data_salt_1800 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.180001-184912.nc')
icesm_data_salt_1800_surf = icesm_data_salt_1800.isel(z_t=0);
icesm_data_salt_1800_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 600, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
#     TLONG                 (nlat, nlon) float64 320.6 321.7 322.8 ... 319.4 319.8
# ...

# %%
icesm_data_salt_1850 = xr.open_dataset('/data/keeling/a/cristi/a/data/CESM_LME/b.ie12.B1850C5CN.f19_g16.LME.002.pop.h.SALT.185001-200512.nc')
icesm_data_salt_1850_surf = icesm_data_salt_1850.isel(z_t=0);
icesm_data_salt_1850_surf.load()
# Out:
# <xarray.Dataset>
# Dimensions:               (moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320, time: 1872, d2: 2)
# Coordinates:
#     z_t                   float32 500.0
#   * z_t_150m              (z_t_150m) float32 500.0 1.5e+03 ... 1.35e+04 1.45e+04
#   * z_w                   (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top               (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot               (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid          (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                 (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
#     ULONG                 (nlat, nlon) float64 321.1 322.3 323.4 ... 319.6 320.0
#     ULAT                  (nlat, nlon) float64 -78.95 -78.95 ... 72.41 72.41
# ...

# %%
r850_sw = icesm_data_d18O_850_surf.R18O
r900_sw = icesm_data_d18O_900_surf.R18O
r1000_sw = icesm_data_d18O_1000_surf.R18O
r1100_sw = icesm_data_d18O_1100_surf.R18O
r1200_sw = icesm_data_d18O_1200_surf.R18O
r1300_sw = icesm_data_d18O_1300_surf.R18O
r1400_sw = icesm_data_d18O_1400_surf.R18O
r1500_sw = icesm_data_d18O_1500_surf.R18O
r1600_sw = icesm_data_d18O_1600_surf.R18O
r1700_sw = icesm_data_d18O_1700_surf.R18O
r1800_sw = icesm_data_d18O_1800_surf.R18O

# %%
icesm_data_d18O_850_surf_sw = (r850_sw -1)*1000
icesm_data_d18O_900_surf_sw = (r900_sw -1)*1000
icesm_data_d18O_1000_surf_sw = (r1000_sw -1)*1000
icesm_data_d18O_1100_surf_sw = (r1100_sw -1)*1000
icesm_data_d18O_1200_surf_sw = (r1200_sw -1)*1000
icesm_data_d18O_1300_surf_sw = (r1300_sw -1)*1000
icesm_data_d18O_1400_surf_sw = (r1400_sw -1)*1000
icesm_data_d18O_1500_surf_sw = (r1500_sw -1)*1000
icesm_data_d18O_1600_surf_sw = (r1600_sw -1)*1000
icesm_data_d18O_1700_surf_sw = (r1700_sw -1)*1000
icesm_data_d18O_1800_surf_sw = (r1800_sw -1)*1000

# %%
icesm_data_salt_850_surf_sw = icesm_data_salt_850_surf.SALT
icesm_data_salt_900_surf_sw = icesm_data_salt_900_surf.SALT
icesm_data_salt_1000_surf_sw = icesm_data_salt_1000_surf.SALT
icesm_data_salt_1100_surf_sw = icesm_data_salt_1100_surf.SALT
icesm_data_salt_1200_surf_sw = icesm_data_salt_1200_surf.SALT
icesm_data_salt_1300_surf_sw = icesm_data_salt_1300_surf.SALT
icesm_data_salt_1400_surf_sw = icesm_data_salt_1400_surf.SALT
icesm_data_salt_1500_surf_sw = icesm_data_salt_1500_surf.SALT
icesm_data_salt_1600_surf_sw = icesm_data_salt_1600_surf.SALT
icesm_data_salt_1700_surf_sw = icesm_data_salt_1700_surf.SALT
icesm_data_salt_1800_surf_sw = icesm_data_salt_1800_surf.SALT

# %%
d18O_mil = xr.concat([icesm_data_d18O_850_surf_sw, icesm_data_d18O_900_surf_sw, icesm_data_d18O_1000_surf_sw, icesm_data_d18O_1100_surf_sw, icesm_data_d18O_1200_surf_sw,icesm_data_d18O_1300_surf_sw,icesm_data_d18O_1400_surf_sw,icesm_data_d18O_1500_surf_sw,icesm_data_d18O_1600_surf_sw,icesm_data_d18O_1700_surf_sw,icesm_data_d18O_1800_surf_sw], dim ='time')

# %%
salt_mil = xr.concat([icesm_data_salt_850_surf_sw, icesm_data_salt_900_surf_sw, icesm_data_salt_1000_surf_sw, icesm_data_salt_1100_surf_sw, icesm_data_salt_1200_surf_sw,icesm_data_salt_1300_surf_sw,icesm_data_salt_1400_surf_sw,icesm_data_salt_1500_surf_sw,icesm_data_salt_1600_surf_sw,icesm_data_salt_1700_surf_sw,icesm_data_salt_1800_surf_sw], dim ='time')

# %%
r1850_sw = icesm_data_d18O_1850_surf.R18O
d18O_last = (r1850_sw -1)*1000
salt_last = icesm_data_salt_1850_surf.SALT

# %%
d18O_mil.to_netcdf('/data/keeling/a/anayrp2/CESM/d18O_mil.nc')

# %%
salt_mil.to_netcdf('/data/keeling/a/anayrp2/CESM/salt_mil.nc')

# %%
d18O_last.to_netcdf('/data/keeling/a/anayrp2/CESM/d18O_last.nc')

# %%
salt_last.to_netcdf('/data/keeling/a/anayrp2/CESM/salt_last.nc')

# %%
d18O_last
# Out:
# <xarray.DataArray 'R18O' (time: 1872, nlat: 384, nlon: 320)>
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [-0.38534403, -0.38665533, -0.3862977 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [-0.36931038, -0.37139654, -0.36901236, ...,         nan,
# ...

# %%
d18O_last_sw = xr.open_dataarray('/data/keeling/a/anayrp2/CESM/d18O_last.nc')

# %%
d18O_last_sw.load()
# Out:
# <xarray.DataArray 'R18O' (time: 1872, nlat: 384, nlon: 320)>
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [-0.38534403, -0.38665533, -0.3862977 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [-0.36931038, -0.37139654, -0.36901236, ...,         nan,
# ...
